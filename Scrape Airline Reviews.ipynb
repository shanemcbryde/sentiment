# %%
import numpy as np
import requests
from bs4 import BeautifulSoup
import pandas as pd
import logging
from collections import defaultdict

# %%
# Scrape airling reviews

# Configure logging to track scraping progress and errors
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

class AirlineReviewScraper:
    def __init__(self, airlines_input, page_size=100, page_count=30):
        # User-specified list of airlines to scrape
        self.airlines_input = airlines_input
        self.page_size = page_size  # Number of reviews per page
        self.page_count = page_count  # Number of pages to scrape per airline

        # Mapping airline code (used in URLs) to full airline names
        self.airline_mapping = {
            'singapore-airlines': 'Singapore Airlines',
            'qatar-airways': 'Qatar Airways',
            'ana-all-nippon-airways': 'All Nippon Airways',
            'emirates': 'Emirates',
            'japan-airlines': 'Japan Airlines',
            'turkish-airlines': 'Turkish Airlines',
            'air-france': 'Air France',
            'cathay-pacific-airways': 'Cathay Pacific Airways',
            'eva-air': 'EVA Air',
            'swiss-international-air-lines': 'Swiss International Air Lines'
        }

        # Primary data dictionary for review attributes
        self.data = {
            'Airline': [],
            'Verified': [],
            'Reviews': [],
            'Type of Traveller': [],
            'Date Flown': [],
            'Class': [],
            'Overall Rating': [],
            'Recommended': []
        }

        # Ratings for specific features stored separately
        self.ratings_data = defaultdict(list)
        self.features = ['Seat Comfort', 'Cabin Staff Service', 'Food & Beverages',
                          'Inflight Entertainment', 'Ground Service', 'Value For Money']

        # Default fill values to handle incomplete records
        self.fill_defaults = {
            'Overall Rating': np.nan,
            'Verified': None,
            'Type of Traveller': None,
            'Class': None,
            'Date Flown': None,
            'Recommended': None
        }

    # Helper to fill lists to a target length with default values
    def fill_with_value(self, lst, length, value=np.nan):
        lst.extend([value] * (length - len(lst)))

    # Extract review metadata from the HTML soup for each individual review
    def extract_review_details(self, soup):
        rows = soup.find_all('tr')
        for row in rows:
            header = row.find('td', class_='review-rating-header')
            value = row.find('td', class_='review-value')
            star = row.find('td', class_='review-rating-stars')

            if header and value:
                header_text = header.text.strip()
                value_text = value.text.strip()

                # Skip placeholder data
                if header_text == 'Date Flown' and value_text == 'Dec-24':
                    continue

                # Assign values to corresponding review fields
                if header_text == 'Type Of Traveller':
                    self.data['Type of Traveller'].append(value_text)
                elif header_text == 'Seat Type':
                    self.data['Class'].append(value_text)
                elif header_text == 'Date Flown':
                    self.data['Date Flown'].append(value_text)
                elif header_text == 'Recommended':
                    val = value_text.strip().lower()
                    if val in {'yes', 'recommended'}:
                        self.data['Recommended'].append(True)
                    elif val in {'no', 'not recommended'}:
                        self.data['Recommended'].append(False)
                    else:
                        self.data['Recommended'].append(None)

            # Count filled stars to determine ratings
            if header and star:
                self.ratings_data[header.text.strip()].append(
                    len(star.find_all('span', class_='star fill')))

    # Scrape one airline by looping through review pages
    def scrape_airline(self, airline_code):
        website = f'https://www.airlinequality.com/airline-reviews/{airline_code}'
        for i in range(1, self.page_count + 1):
            try:
                logging.info(f"Scraping data from {airline_code} Page {i}")
                url = f"{website}/page/{i}/?sortby=post_date%3ADesc&pagesize={self.page_size}"
                response = requests.get(url, timeout=10)
                response.raise_for_status()  # Raise exception for failed requests
                soup = BeautifulSoup(response.content, 'html.parser')

                # Extract overall rating from review cards
                for rating in soup.find_all('div', {'itemprop': 'reviewRating'}):
                    rating_value = rating.find("span", {"itemprop": "ratingValue"})
                    if rating_value:
                        try:
                            self.data['Overall Rating'].append(int(rating_value.get_text()))
                        except ValueError:
                            self.data['Overall Rating'].append(np.nan)

                # Verified status and review content
                for para in soup.find_all("em"):
                    self.data['Verified'].append(para.get_text())
                for para in soup.find_all("div", {"class": "text_content"}):
                    self.data['Reviews'].append(para.get_text())
                    self.data['Airline'].append(self.airline_mapping.get(airline_code))

                # Detailed review information (e.g. seat comfort, date flown)
                self.extract_review_details(soup)

            except requests.exceptions.RequestException as e:
                logging.error(f"Failed to scrape {airline_code} Page {i}: {e}")

        logging.info(f"Total records scraped for {airline_code}: {len(self.data['Reviews'])}")

    # Ensure all lists are equal in length before saving
    def equalize_lengths(self, target_length):
        for key in self.data:
            self.fill_with_value(self.data[key], target_length, self.fill_defaults.get(key, np.nan))
        for feat_name in self.features:
            self.fill_with_value(self.ratings_data[feat_name], target_length, np.nan)

    # Convert scraped data to DataFrame and save as CSV
    def save_to_csv(self, filename='airlines_reviews.csv'):
        df = pd.DataFrame({
            **self.data,
            'Seat Comfort': self.ratings_data['Seat Comfort'],
            'Staff Service': self.ratings_data['Cabin Staff Service'],
            'Ground Service': self.ratings_data['Ground Service'],
            'Food & Beverages': self.ratings_data['Food & Beverages'],
            'Inflight Entertainment': self.ratings_data['Inflight Entertainment'],
            'Value For Money': self.ratings_data['Value For Money']
        })

        # Clean up and standardize values
        df['Reviews'] = df['Reviews'].replace('None', np.nan)
        df.dropna(subset=['Reviews', 'Overall Rating', 'Recommended'], inplace=True)
        df['Verified'] = df['Verified'].replace({'Trip Verified': True, 'Not Verified': False})
        df['Overall Rating'] = pd.to_numeric(df['Overall Rating'], errors='coerce')

        df.to_csv(filename, index=False)
        logging.info(f"Data saved to '{filename}'")

    # Orchestrates the full scraping process across all airlines
    def run(self):
        for airline_code in self.airlines_input:
            self.scrape_airline(airline_code)
            self.equalize_lengths(len(self.data['Reviews']))
        self.save_to_csv()

# Entrypoint for the script
if __name__ == "__main__":
    airlines = [
        'singapore-airlines', 'qatar-airways', 'ana-all-nippon-airways', 'emirates',
        'japan-airlines', 'turkish-airlines', 'air-france', 'cathay-pacific-airways',
        'eva-air', 'swiss-international-air-lines'
    ]
    scraper = AirlineReviewScraper(airlines)
    scraper.run()
# Out:
# 2025-08-05 16:14:58,781 - INFO - Scraping data from singapore-airlines Page 1
# 2025-08-05 16:15:01,336 - INFO - Scraping data from singapore-airlines Page 2
# 2025-08-05 16:15:03,301 - INFO - Scraping data from singapore-airlines Page 3
# 2025-08-05 16:15:05,326 - INFO - Scraping data from singapore-airlines Page 4
# 2025-08-05 16:15:06,952 - INFO - Scraping data from singapore-airlines Page 5
# 2025-08-05 16:15:08,455 - INFO - Scraping data from singapore-airlines Page 6
# 2025-08-05 16:15:09,865 - INFO - Scraping data from singapore-airlines Page 7
# 2025-08-05 16:15:11,625 - INFO - Scraping data from singapore-airlines Page 8
# 2025-08-05 16:15:13,562 - INFO - Scraping data from singapore-airlines Page 9
# 2025-08-05 16:15:15,148 - INFO - Scraping data from singapore-airlines Page 10
# 2025-08-05 16:15:16,872 - INFO - Scraping data from singapore-airlines Page 11
# 2025-08-05 16:15:18,428 - INFO - Scraping data from singapore-airlines Page 12
# 2025-08-05 16:15:20,064 - INFO - Scraping data from singapore-airlines Page 13
# 2025-08-05 16:15:21,524 - INFO - Scraping data from singapore-airlines Page 14
# 2025-08-05 16:15:22,909 - INFO - Scraping data from singapore-airlines Page 15
# 2025-08-05 16:15:24,304 - INFO - Scraping data from singapore-airlines Page 16
# 2025-08-05 16:15:25,612 - INFO - Scraping data from singapore-airlines Page 17
# 2025-08-05 16:15:26,687 - INFO - Scraping data from singapore-airlines Page 18
# 2025-08-05 16:15:27,315 - INFO - Scraping data from singapore-airlines Page 19
# 2025-08-05 16:15:27,977 - INFO - Scraping data from singapore-airlines Page 20
# 2025-08-05 16:15:28,595 - INFO - Scraping data from singapore-airlines Page 21
# 2025-08-05 16:15:29,641 - INFO - Scraping data from singapore-airlines Page 22
# 2025-08-05 16:15:30,320 - INFO - Scraping data from singapore-airlines Page 23
# 2025-08-05 16:15:30,935 - INFO - Scraping data from singapore-airlines Page 24
# 2025-08-05 16:15:31,602 - INFO - Scraping data from singapore-airlines Page 25
# 2025-08-05 16:15:32,361 - INFO - Scraping data from singapore-airlines Page 26
# 2025-08-05 16:15:33,023 - INFO - Scraping data from singapore-airlines Page 27
# 2025-08-05 16:15:33,689 - INFO - Scraping data from singapore-airlines Page 28
# 2025-08-05 16:15:34,381 - INFO - Scraping data from singapore-airlines Page 29
# 2025-08-05 16:15:35,011 - INFO - Scraping data from singapore-airlines Page 30
# 2025-08-05 16:15:35,616 - INFO - Total records scraped for singapore-airlines: 1661
# 2025-08-05 16:15:35,617 - INFO - Scraping data from qatar-airways Page 1
# 2025-08-05 16:15:37,273 - INFO - Scraping data from qatar-airways Page 2
# 2025-08-05 16:15:38,856 - INFO - Scraping data from qatar-airways Page 3
# 2025-08-05 16:15:40,451 - INFO - Scraping data from qatar-airways Page 4
# 2025-08-05 16:15:42,029 - INFO - Scraping data from qatar-airways Page 5
# 2025-08-05 16:15:43,605 - INFO - Scraping data from qatar-airways Page 6
# 2025-08-05 16:15:45,342 - INFO - Scraping data from qatar-airways Page 7
# 2025-08-05 16:15:46,917 - INFO - Scraping data from qatar-airways Page 8
# 2025-08-05 16:15:48,542 - INFO - Scraping data from qatar-airways Page 9
# 2025-08-05 16:15:50,236 - INFO - Scraping data from qatar-airways Page 10
# 2025-08-05 16:15:52,877 - INFO - Scraping data from qatar-airways Page 11
# 2025-08-05 16:15:54,473 - INFO - Scraping data from qatar-airways Page 12
# 2025-08-05 16:15:56,037 - INFO - Scraping data from qatar-airways Page 13
# 2025-08-05 16:15:57,639 - INFO - Scraping data from qatar-airways Page 14
# 2025-08-05 16:15:59,372 - INFO - Scraping data from qatar-airways Page 15
# 2025-08-05 16:16:01,406 - INFO - Scraping data from qatar-airways Page 16
# 2025-08-05 16:16:03,169 - INFO - Scraping data from qatar-airways Page 17
# 2025-08-05 16:16:04,824 - INFO - Scraping data from qatar-airways Page 18
# 2025-08-05 16:16:06,436 - INFO - Scraping data from qatar-airways Page 19
# 2025-08-05 16:16:08,007 - INFO - Scraping data from qatar-airways Page 20
# 2025-08-05 16:16:09,652 - INFO - Scraping data from qatar-airways Page 21
# 2025-08-05 16:16:11,263 - INFO - Scraping data from qatar-airways Page 22
# 2025-08-05 16:16:12,949 - INFO - Scraping data from qatar-airways Page 23
# 2025-08-05 16:16:14,547 - INFO - Scraping data from qatar-airways Page 24
# 2025-08-05 16:16:15,992 - INFO - Scraping data from qatar-airways Page 25
# 2025-08-05 16:16:17,231 - INFO - Scraping data from qatar-airways Page 26
# 2025-08-05 16:16:18,516 - INFO - Scraping data from qatar-airways Page 27
# 2025-08-05 16:16:19,365 - INFO - Scraping data from qatar-airways Page 28
# 2025-08-05 16:16:19,983 - INFO - Scraping data from qatar-airways Page 29
# 2025-08-05 16:16:20,618 - INFO - Scraping data from qatar-airways Page 30
# 2025-08-05 16:16:21,391 - INFO - Total records scraped for qatar-airways: 4286
# 2025-08-05 16:16:21,392 - INFO - Scraping data from ana-all-nippon-airways Page 1
# 2025-08-05 16:16:22,988 - INFO - Scraping data from ana-all-nippon-airways Page 2
# 2025-08-05 16:16:24,534 - INFO - Scraping data from ana-all-nippon-airways Page 3
# 2025-08-05 16:16:26,029 - INFO - Scraping data from ana-all-nippon-airways Page 4
# 2025-08-05 16:16:27,432 - INFO - Scraping data from ana-all-nippon-airways Page 5
# 2025-08-05 16:16:28,706 - INFO - Scraping data from ana-all-nippon-airways Page 6
# 2025-08-05 16:16:29,893 - INFO - Scraping data from ana-all-nippon-airways Page 7
# 2025-08-05 16:16:30,681 - INFO - Scraping data from ana-all-nippon-airways Page 8
# 2025-08-05 16:16:31,306 - INFO - Scraping data from ana-all-nippon-airways Page 9
# 2025-08-05 16:16:31,936 - INFO - Scraping data from ana-all-nippon-airways Page 10
# 2025-08-05 16:16:32,600 - INFO - Scraping data from ana-all-nippon-airways Page 11
# 2025-08-05 16:16:33,242 - INFO - Scraping data from ana-all-nippon-airways Page 12
# 2025-08-05 16:16:33,873 - INFO - Scraping data from ana-all-nippon-airways Page 13
# 2025-08-05 16:16:34,455 - INFO - Scraping data from ana-all-nippon-airways Page 14
# 2025-08-05 16:16:35,050 - INFO - Scraping data from ana-all-nippon-airways Page 15
# 2025-08-05 16:16:35,627 - INFO - Scraping data from ana-all-nippon-airways Page 16
# 2025-08-05 16:16:36,255 - INFO - Scraping data from ana-all-nippon-airways Page 17
# 2025-08-05 16:16:36,865 - INFO - Scraping data from ana-all-nippon-airways Page 18
# 2025-08-05 16:16:37,548 - INFO - Scraping data from ana-all-nippon-airways Page 19
# 2025-08-05 16:16:38,143 - INFO - Scraping data from ana-all-nippon-airways Page 20
# 2025-08-05 16:16:38,755 - INFO - Scraping data from ana-all-nippon-airways Page 21
# 2025-08-05 16:16:39,322 - INFO - Scraping data from ana-all-nippon-airways Page 22
# 2025-08-05 16:16:40,030 - INFO - Scraping data from ana-all-nippon-airways Page 23
# 2025-08-05 16:16:40,670 - INFO - Scraping data from ana-all-nippon-airways Page 24
# 2025-08-05 16:16:41,250 - INFO - Scraping data from ana-all-nippon-airways Page 25
# 2025-08-05 16:16:41,885 - INFO - Scraping data from ana-all-nippon-airways Page 26
# 2025-08-05 16:16:42,488 - INFO - Scraping data from ana-all-nippon-airways Page 27
# 2025-08-05 16:16:43,105 - INFO - Scraping data from ana-all-nippon-airways Page 28
# 2025-08-05 16:16:43,870 - INFO - Scraping data from ana-all-nippon-airways Page 29
# 2025-08-05 16:16:44,528 - INFO - Scraping data from ana-all-nippon-airways Page 30
# 2025-08-05 16:16:45,126 - INFO - Total records scraped for ana-all-nippon-airways: 4904
# 2025-08-05 16:16:45,128 - INFO - Scraping data from emirates Page 1
# 2025-08-05 16:16:46,817 - INFO - Scraping data from emirates Page 2
# 2025-08-05 16:16:48,416 - INFO - Scraping data from emirates Page 3
# 2025-08-05 16:16:50,104 - INFO - Scraping data from emirates Page 4
# 2025-08-05 16:16:51,833 - INFO - Scraping data from emirates Page 5
# 2025-08-05 16:16:53,301 - INFO - Scraping data from emirates Page 6
# 2025-08-05 16:16:54,945 - INFO - Scraping data from emirates Page 7
# 2025-08-05 16:16:56,479 - INFO - Scraping data from emirates Page 8
# 2025-08-05 16:16:57,989 - INFO - Scraping data from emirates Page 9
# 2025-08-05 16:16:59,349 - INFO - Scraping data from emirates Page 10
# 2025-08-05 16:17:00,981 - INFO - Scraping data from emirates Page 11
# 2025-08-05 16:17:02,511 - INFO - Scraping data from emirates Page 12
# 2025-08-05 16:17:04,075 - INFO - Scraping data from emirates Page 13
# 2025-08-05 16:17:05,471 - INFO - Scraping data from emirates Page 14
# 2025-08-05 16:17:07,080 - INFO - Scraping data from emirates Page 15
# 2025-08-05 16:17:08,611 - INFO - Scraping data from emirates Page 16
# 2025-08-05 16:17:10,126 - INFO - Scraping data from emirates Page 17
# 2025-08-05 16:17:11,744 - INFO - Scraping data from emirates Page 18
# 2025-08-05 16:17:13,529 - INFO - Scraping data from emirates Page 19
# 2025-08-05 16:17:14,864 - INFO - Scraping data from emirates Page 20
# 2025-08-05 16:17:16,095 - INFO - Scraping data from emirates Page 21
# 2025-08-05 16:17:17,344 - INFO - Scraping data from emirates Page 22
# 2025-08-05 16:17:18,575 - INFO - Scraping data from emirates Page 23
# 2025-08-05 16:17:19,831 - INFO - Scraping data from emirates Page 24
# 2025-08-05 16:17:21,055 - INFO - Scraping data from emirates Page 25
# 2025-08-05 16:17:22,099 - INFO - Scraping data from emirates Page 26
# 2025-08-05 16:17:22,740 - INFO - Scraping data from emirates Page 27
# 2025-08-05 16:17:23,360 - INFO - Scraping data from emirates Page 28
# 2025-08-05 16:17:23,955 - INFO - Scraping data from emirates Page 29
# 2025-08-05 16:17:24,618 - INFO - Scraping data from emirates Page 30
# 2025-08-05 16:17:25,262 - INFO - Total records scraped for emirates: 7355
# 2025-08-05 16:17:25,263 - INFO - Scraping data from japan-airlines Page 1
# 2025-08-05 16:17:26,553 - INFO - Scraping data from japan-airlines Page 2
# 2025-08-05 16:17:28,288 - INFO - Scraping data from japan-airlines Page 3
# 2025-08-05 16:17:29,837 - INFO - Scraping data from japan-airlines Page 4
# 2025-08-05 16:17:31,137 - INFO - Scraping data from japan-airlines Page 5
# 2025-08-05 16:17:32,019 - INFO - Scraping data from japan-airlines Page 6
# 2025-08-05 16:17:32,638 - INFO - Scraping data from japan-airlines Page 7
# 2025-08-05 16:17:33,210 - INFO - Scraping data from japan-airlines Page 8
# 2025-08-05 16:17:33,890 - INFO - Scraping data from japan-airlines Page 9
# 2025-08-05 16:17:34,510 - INFO - Scraping data from japan-airlines Page 10
# 2025-08-05 16:17:35,131 - INFO - Scraping data from japan-airlines Page 11
# 2025-08-05 16:17:35,704 - INFO - Scraping data from japan-airlines Page 12
# 2025-08-05 16:17:36,304 - INFO - Scraping data from japan-airlines Page 13
# 2025-08-05 16:17:36,887 - INFO - Scraping data from japan-airlines Page 14
# 2025-08-05 16:17:37,526 - INFO - Scraping data from japan-airlines Page 15
# 2025-08-05 16:17:38,139 - INFO - Scraping data from japan-airlines Page 16
# 2025-08-05 16:17:38,721 - INFO - Scraping data from japan-airlines Page 17
# 2025-08-05 16:17:39,325 - INFO - Scraping data from japan-airlines Page 18
# 2025-08-05 16:17:39,902 - INFO - Scraping data from japan-airlines Page 19
# 2025-08-05 16:17:40,530 - INFO - Scraping data from japan-airlines Page 20
# 2025-08-05 16:17:41,137 - INFO - Scraping data from japan-airlines Page 21
# 2025-08-05 16:17:41,812 - INFO - Scraping data from japan-airlines Page 22
# 2025-08-05 16:17:42,410 - INFO - Scraping data from japan-airlines Page 23
# 2025-08-05 16:17:43,028 - INFO - Scraping data from japan-airlines Page 24
# 2025-08-05 16:17:43,643 - INFO - Scraping data from japan-airlines Page 25
# 2025-08-05 16:17:44,259 - INFO - Scraping data from japan-airlines Page 26
# 2025-08-05 16:17:44,861 - INFO - Scraping data from japan-airlines Page 27
# 2025-08-05 16:17:45,462 - INFO - Scraping data from japan-airlines Page 28
# 2025-08-05 16:17:46,071 - INFO - Scraping data from japan-airlines Page 29
# 2025-08-05 16:17:46,690 - INFO - Scraping data from japan-airlines Page 30
# 2025-08-05 16:17:47,283 - INFO - Total records scraped for japan-airlines: 7688
# 2025-08-05 16:17:47,284 - INFO - Scraping data from turkish-airlines Page 1
# 2025-08-05 16:17:48,901 - INFO - Scraping data from turkish-airlines Page 2
# 2025-08-05 16:17:50,403 - INFO - Scraping data from turkish-airlines Page 3
# 2025-08-05 16:17:52,022 - INFO - Scraping data from turkish-airlines Page 4
# 2025-08-05 16:17:53,541 - INFO - Scraping data from turkish-airlines Page 5
# 2025-08-05 16:17:55,014 - INFO - Scraping data from turkish-airlines Page 6
# 2025-08-05 16:17:56,503 - INFO - Scraping data from turkish-airlines Page 7
# 2025-08-05 16:17:58,000 - INFO - Scraping data from turkish-airlines Page 8
# 2025-08-05 16:17:59,402 - INFO - Scraping data from turkish-airlines Page 9
# 2025-08-05 16:18:01,059 - INFO - Scraping data from turkish-airlines Page 10
# 2025-08-05 16:18:02,759 - INFO - Scraping data from turkish-airlines Page 11
# 2025-08-05 16:18:04,185 - INFO - Scraping data from turkish-airlines Page 12
# 2025-08-05 16:18:05,666 - INFO - Scraping data from turkish-airlines Page 13
# 2025-08-05 16:18:07,195 - INFO - Scraping data from turkish-airlines Page 14
# 2025-08-05 16:18:08,722 - INFO - Scraping data from turkish-airlines Page 15
# 2025-08-05 16:18:10,243 - INFO - Scraping data from turkish-airlines Page 16
# 2025-08-05 16:18:11,822 - INFO - Scraping data from turkish-airlines Page 17
# 2025-08-05 16:18:13,759 - INFO - Scraping data from turkish-airlines Page 18
# 2025-08-05 16:18:15,494 - INFO - Scraping data from turkish-airlines Page 19
# 2025-08-05 16:18:17,087 - INFO - Scraping data from turkish-airlines Page 20
# 2025-08-05 16:18:18,618 - INFO - Scraping data from turkish-airlines Page 21
# 2025-08-05 16:18:20,060 - INFO - Scraping data from turkish-airlines Page 22
# 2025-08-05 16:18:21,567 - INFO - Scraping data from turkish-airlines Page 23
# 2025-08-05 16:18:23,281 - INFO - Scraping data from turkish-airlines Page 24
# 2025-08-05 16:18:24,804 - INFO - Scraping data from turkish-airlines Page 25
# 2025-08-05 16:18:26,227 - INFO - Scraping data from turkish-airlines Page 26
# 2025-08-05 16:18:27,539 - INFO - Scraping data from turkish-airlines Page 27
# 2025-08-05 16:18:28,949 - INFO - Scraping data from turkish-airlines Page 28
# 2025-08-05 16:18:30,557 - INFO - Scraping data from turkish-airlines Page 29
# 2025-08-05 16:18:31,329 - INFO - Scraping data from turkish-airlines Page 30
# 2025-08-05 16:18:32,042 - INFO - Total records scraped for turkish-airlines: 10477
# 2025-08-05 16:18:32,043 - INFO - Scraping data from air-france Page 1
# 2025-08-05 16:18:33,470 - INFO - Scraping data from air-france Page 2
# 2025-08-05 16:18:35,175 - INFO - Scraping data from air-france Page 3
# 2025-08-05 16:18:36,602 - INFO - Scraping data from air-france Page 4
# 2025-08-05 16:18:38,169 - INFO - Scraping data from air-france Page 5
# 2025-08-05 16:18:39,638 - INFO - Scraping data from air-france Page 6
# 2025-08-05 16:18:41,097 - INFO - Scraping data from air-france Page 7
# 2025-08-05 16:18:42,550 - INFO - Scraping data from air-france Page 8
# 2025-08-05 16:18:43,952 - INFO - Scraping data from air-france Page 9
# 2025-08-05 16:18:45,351 - INFO - Scraping data from air-france Page 10
# 2025-08-05 16:18:47,032 - INFO - Scraping data from air-france Page 11
# 2025-08-05 16:18:48,441 - INFO - Scraping data from air-france Page 12
# 2025-08-05 16:18:49,753 - INFO - Scraping data from air-france Page 13
# 2025-08-05 16:18:51,000 - INFO - Scraping data from air-france Page 14
# 2025-08-05 16:18:52,311 - INFO - Scraping data from air-france Page 15
# 2025-08-05 16:18:53,267 - INFO - Scraping data from air-france Page 16
# 2025-08-05 16:18:53,909 - INFO - Scraping data from air-france Page 17
# 2025-08-05 16:18:54,541 - INFO - Scraping data from air-france Page 18
# 2025-08-05 16:18:55,214 - INFO - Scraping data from air-france Page 19
# 2025-08-05 16:18:55,807 - INFO - Scraping data from air-france Page 20
# 2025-08-05 16:18:56,437 - INFO - Scraping data from air-france Page 21
# 2025-08-05 16:18:57,019 - INFO - Scraping data from air-france Page 22
# 2025-08-05 16:18:57,601 - INFO - Scraping data from air-france Page 23
# 2025-08-05 16:18:58,222 - INFO - Scraping data from air-france Page 24
# 2025-08-05 16:18:58,799 - INFO - Scraping data from air-france Page 25
# 2025-08-05 16:18:59,421 - INFO - Scraping data from air-france Page 26
# 2025-08-05 16:18:59,991 - INFO - Scraping data from air-france Page 27
# 2025-08-05 16:19:00,610 - INFO - Scraping data from air-france Page 28
# 2025-08-05 16:19:01,327 - INFO - Scraping data from air-france Page 29
# 2025-08-05 16:19:01,967 - INFO - Scraping data from air-france Page 30
# 2025-08-05 16:19:02,611 - INFO - Total records scraped for air-france: 11919
# 2025-08-05 16:19:02,612 - INFO - Scraping data from cathay-pacific-airways Page 1
# 2025-08-05 16:19:04,061 - INFO - Scraping data from cathay-pacific-airways Page 2
# 2025-08-05 16:19:05,563 - INFO - Scraping data from cathay-pacific-airways Page 3
# 2025-08-05 16:19:07,089 - INFO - Scraping data from cathay-pacific-airways Page 4
# 2025-08-05 16:19:08,768 - INFO - Scraping data from cathay-pacific-airways Page 5
# 2025-08-05 16:19:10,249 - INFO - Scraping data from cathay-pacific-airways Page 6
# 2025-08-05 16:19:11,892 - INFO - Scraping data from cathay-pacific-airways Page 7
# 2025-08-05 16:19:13,777 - INFO - Scraping data from cathay-pacific-airways Page 8
# 2025-08-05 16:19:15,277 - INFO - Scraping data from cathay-pacific-airways Page 9
# 2025-08-05 16:19:16,802 - INFO - Scraping data from cathay-pacific-airways Page 10
# 2025-08-05 16:19:18,238 - INFO - Scraping data from cathay-pacific-airways Page 11
# 2025-08-05 16:19:19,525 - INFO - Scraping data from cathay-pacific-airways Page 12
# 2025-08-05 16:19:20,833 - INFO - Scraping data from cathay-pacific-airways Page 13
# 2025-08-05 16:19:22,180 - INFO - Scraping data from cathay-pacific-airways Page 14
# 2025-08-05 16:19:23,478 - INFO - Scraping data from cathay-pacific-airways Page 15
# 2025-08-05 16:19:24,783 - INFO - Scraping data from cathay-pacific-airways Page 16
# 2025-08-05 16:19:25,401 - INFO - Scraping data from cathay-pacific-airways Page 17
# 2025-08-05 16:19:25,998 - INFO - Scraping data from cathay-pacific-airways Page 18
# 2025-08-05 16:19:26,595 - INFO - Scraping data from cathay-pacific-airways Page 19
# 2025-08-05 16:19:27,198 - INFO - Scraping data from cathay-pacific-airways Page 20
# 2025-08-05 16:19:27,910 - INFO - Scraping data from cathay-pacific-airways Page 21
# 2025-08-05 16:19:28,600 - INFO - Scraping data from cathay-pacific-airways Page 22
# 2025-08-05 16:19:29,605 - INFO - Scraping data from cathay-pacific-airways Page 23
# 2025-08-05 16:19:30,229 - INFO - Scraping data from cathay-pacific-airways Page 24
# 2025-08-05 16:19:30,845 - INFO - Scraping data from cathay-pacific-airways Page 25
# 2025-08-05 16:19:31,444 - INFO - Scraping data from cathay-pacific-airways Page 26
# 2025-08-05 16:19:32,038 - INFO - Scraping data from cathay-pacific-airways Page 27
# 2025-08-05 16:19:32,674 - INFO - Scraping data from cathay-pacific-airways Page 28
# 2025-08-05 16:19:33,326 - INFO - Scraping data from cathay-pacific-airways Page 29
# 2025-08-05 16:19:33,980 - INFO - Scraping data from cathay-pacific-airways Page 30
# 2025-08-05 16:19:34,685 - INFO - Total records scraped for cathay-pacific-airways: 13420
# 2025-08-05 16:19:34,687 - INFO - Scraping data from eva-air Page 1
# 2025-08-05 16:19:36,308 - INFO - Scraping data from eva-air Page 2
# 2025-08-05 16:19:37,768 - INFO - Scraping data from eva-air Page 3
# 2025-08-05 16:19:39,313 - INFO - Scraping data from eva-air Page 4
# 2025-08-05 16:19:40,699 - INFO - Scraping data from eva-air Page 5
# 2025-08-05 16:19:42,029 - INFO - Scraping data from eva-air Page 6
# 2025-08-05 16:19:43,290 - INFO - Scraping data from eva-air Page 7
# 2025-08-05 16:19:44,377 - INFO - Scraping data from eva-air Page 8
# 2025-08-05 16:19:45,007 - INFO - Scraping data from eva-air Page 9
# 2025-08-05 16:19:45,710 - INFO - Scraping data from eva-air Page 10
# 2025-08-05 16:19:46,367 - INFO - Scraping data from eva-air Page 11
# 2025-08-05 16:19:46,969 - INFO - Scraping data from eva-air Page 12
# 2025-08-05 16:19:47,660 - INFO - Scraping data from eva-air Page 13
# 2025-08-05 16:19:48,355 - INFO - Scraping data from eva-air Page 14
# 2025-08-05 16:19:49,047 - INFO - Scraping data from eva-air Page 15
# 2025-08-05 16:19:49,654 - INFO - Scraping data from eva-air Page 16
# 2025-08-05 16:19:50,309 - INFO - Scraping data from eva-air Page 17
# 2025-08-05 16:19:50,938 - INFO - Scraping data from eva-air Page 18
# 2025-08-05 16:19:51,531 - INFO - Scraping data from eva-air Page 19
# 2025-08-05 16:19:52,128 - INFO - Scraping data from eva-air Page 20
# 2025-08-05 16:19:52,732 - INFO - Scraping data from eva-air Page 21
# 2025-08-05 16:19:53,357 - INFO - Scraping data from eva-air Page 22
# 2025-08-05 16:19:54,072 - INFO - Scraping data from eva-air Page 23
# 2025-08-05 16:19:54,649 - INFO - Scraping data from eva-air Page 24
# 2025-08-05 16:19:55,215 - INFO - Scraping data from eva-air Page 25
# 2025-08-05 16:19:55,821 - INFO - Scraping data from eva-air Page 26
# 2025-08-05 16:19:56,469 - INFO - Scraping data from eva-air Page 27
# 2025-08-05 16:19:57,080 - INFO - Scraping data from eva-air Page 28
# 2025-08-05 16:19:57,745 - INFO - Scraping data from eva-air Page 29
# 2025-08-05 16:19:58,336 - INFO - Scraping data from eva-air Page 30
# 2025-08-05 16:19:58,980 - INFO - Total records scraped for eva-air: 14085
# 2025-08-05 16:19:58,981 - INFO - Scraping data from swiss-international-air-lines Page 1
# 2025-08-05 16:20:00,458 - INFO - Scraping data from swiss-international-air-lines Page 2
# 2025-08-05 16:20:02,254 - INFO - Scraping data from swiss-international-air-lines Page 3
# 2025-08-05 16:20:03,803 - INFO - Scraping data from swiss-international-air-lines Page 4
# 2025-08-05 16:20:05,166 - INFO - Scraping data from swiss-international-air-lines Page 5
# 2025-08-05 16:20:06,598 - INFO - Scraping data from swiss-international-air-lines Page 6
# 2025-08-05 16:20:08,048 - INFO - Scraping data from swiss-international-air-lines Page 7
# 2025-08-05 16:20:09,582 - INFO - Scraping data from swiss-international-air-lines Page 8
# 2025-08-05 16:20:11,056 - INFO - Scraping data from swiss-international-air-lines Page 9
# 2025-08-05 16:20:12,362 - INFO - Scraping data from swiss-international-air-lines Page 10
# 2025-08-05 16:20:13,924 - INFO - Scraping data from swiss-international-air-lines Page 11
# 2025-08-05 16:20:15,103 - INFO - Scraping data from swiss-international-air-lines Page 12
# 2025-08-05 16:20:15,881 - INFO - Scraping data from swiss-international-air-lines Page 13
# 2025-08-05 16:20:16,485 - INFO - Scraping data from swiss-international-air-lines Page 14
# 2025-08-05 16:20:17,053 - INFO - Scraping data from swiss-international-air-lines Page 15
# 2025-08-05 16:20:17,686 - INFO - Scraping data from swiss-international-air-lines Page 16
# 2025-08-05 16:20:18,324 - INFO - Scraping data from swiss-international-air-lines Page 17
# 2025-08-05 16:20:19,002 - INFO - Scraping data from swiss-international-air-lines Page 18
# 2025-08-05 16:20:19,640 - INFO - Scraping data from swiss-international-air-lines Page 19
# 2025-08-05 16:20:20,259 - INFO - Scraping data from swiss-international-air-lines Page 20
# 2025-08-05 16:20:20,884 - INFO - Scraping data from swiss-international-air-lines Page 21
# 2025-08-05 16:20:21,485 - INFO - Scraping data from swiss-international-air-lines Page 22
# 2025-08-05 16:20:22,126 - INFO - Scraping data from swiss-international-air-lines Page 23
# 2025-08-05 16:20:22,762 - INFO - Scraping data from swiss-international-air-lines Page 24
# 2025-08-05 16:20:23,406 - INFO - Scraping data from swiss-international-air-lines Page 25
# 2025-08-05 16:20:23,997 - INFO - Scraping data from swiss-international-air-lines Page 26
# 2025-08-05 16:20:24,631 - INFO - Scraping data from swiss-international-air-lines Page 27
# 2025-08-05 16:20:25,235 - INFO - Scraping data from swiss-international-air-lines Page 28
# 2025-08-05 16:20:25,821 - INFO - Scraping data from swiss-international-air-lines Page 29
# 2025-08-05 16:20:26,432 - INFO - Scraping data from swiss-international-air-lines Page 30
# 2025-08-05 16:20:27,018 - INFO - Total records scraped for swiss-international-air-lines: 15208
# 2025-08-05 16:20:27,202 - INFO - Data saved to 'airlines_reviews.csv'
